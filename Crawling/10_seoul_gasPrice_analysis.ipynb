# %% [markdown]
# # 서울시 구별 주유소 데이터 분석 및 시각

# %%
import numpy as np
import pandas as pd
import requests
from urllib.parse import quote
import folium, json

# %%
df = pd.read_csv('./gasData/서울_주유소(230418).csv')
df.head()
# Out:
#             상호                       주소    가격 셀프      상표    구
# 0  (주)보성 세곡주유소    서울 강남구  헌릉로 731 (세곡동)  1623  Y   SK에너지  강남구
# 1      자곡셀프주유소    서울 강남구 밤고개로 120 (자곡동)  1669  Y   SK에너지  강남구
# 2       삼성동주유소    서울 강남구 테헤란로 619 (삼성동)  1684  Y  현대오일뱅크  강남구
# 3        방죽주유소    서울 강남구 밤고개로 215 (율현동)  1687  Y   GS칼텍스  강남구
# 4     오일프러스 셀프  서울 강남구 남부순환로 2651 (도곡동)  1704  Y   SK에너지  강남구

# %%
# 구별 집계 분석
gu_mm = df.groupby('구')['가격'].agg(['mean', 'min', 'max'])
gu_mm
# Out:
#              mean   min   max
# 구
# 강남구   1942.294118  1623  2578
# 강동구   1735.000000  1669  1978
# 강북구   1649.916667  1629  1707
# 강서구   1696.818182  1628  1995
# 관악구   1744.714286  1685  1852
# 광진구   1684.538462  1654  1748
# 구로구   1737.200000  1645  2198
# 금천구   1699.090909  1665  1769
# 노원구   1699.428571  1629  1795
# 도봉구   1673.687500  1639  1767
# 동대문구  1687.055556  1615  1790
# 동작구   1738.333333  1639  1835
# 마포구   1699.909091  1637  1764
# 서대문구  1669.428571  1619  1728
# 서초구   1737.033333  1594  1989
# 성동구   1797.062500  1625  2148
# 성북구   1693.782609  1625  1892
# 송파구   1684.827586  1633  1848
# 양천구   1676.291667  1595  1779
# 영등포구  1731.851852  1625  2199
# 용산구   2169.500000  1948  2749
# 은평구   1639.000000  1604  1748
# 종로구   1951.000000  1689  2240
# 중구    2053.400000  1649  2753
# 중랑구   1661.153846  1635  1719

# %%
# 해당구에서 최대값 최소값만 구하기
# 예 강남구
_, mi, ma = gu_mm.loc['강남구']
mi, ma = int(mi), int(ma)
mi, ma
# Out:
# (1623, 2578)

# %%
# 컬럼을 하나 추가하여 최대값인지 최속값인지 결정해서 넣을 예정
df['mm'] = np.zeros(df.shape[0], int)
df.head()
# Out:
#             상호                       주소    가격 셀프      상표    구  mm
# 0  (주)보성 세곡주유소    서울 강남구  헌릉로 731 (세곡동)  1623  Y   SK에너지  강남구   0
# 1      자곡셀프주유소    서울 강남구 밤고개로 120 (자곡동)  1669  Y   SK에너지  강남구   0
# 2       삼성동주유소    서울 강남구 테헤란로 619 (삼성동)  1684  Y  현대오일뱅크  강남구   0
# 3        방죽주유소    서울 강남구 밤고개로 215 (율현동)  1687  Y   GS칼텍스  강남구   0
# 4     오일프러스 셀프  서울 강남구 남부순환로 2651 (도곡동)  1704  Y   SK에너지  강남구   0

# %%
# mm 컬럼에 최소값이 같으면 1을 넣고 최대값과 같으면 2를 넣을것
for gu in gu_mm.index:
    _, mi, ma = gu_mm.loc[gu]
    mi, ma = int(mi) , int(ma)
    for i in df.index:
        if df.가격[i] == mi and df.구[i] == gu:
            df.mm[i] = 1
        if df.가격[i] == ma and df.구[i] == gu:
            df.mm[i] = 2
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10092\1260248008.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.mm[i] = 1
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10092\1260248008.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.mm[i] = 2

# %%
df.head()
# Out:
#             상호                       주소    가격 셀프      상표    구  mm
# 0  (주)보성 세곡주유소    서울 강남구  헌릉로 731 (세곡동)  1623  Y   SK에너지  강남구   1
# 1      자곡셀프주유소    서울 강남구 밤고개로 120 (자곡동)  1669  Y   SK에너지  강남구   0
# 2       삼성동주유소    서울 강남구 테헤란로 619 (삼성동)  1684  Y  현대오일뱅크  강남구   0
# 3        방죽주유소    서울 강남구 밤고개로 215 (율현동)  1687  Y   GS칼텍스  강남구   0
# 4     오일프러스 셀프  서울 강남구 남부순환로 2651 (도곡동)  1704  Y   SK에너지  강남구   0

# %%
# mm컬럼에 데이터가 있는 행만 추출
df1 = df[df.mm !=0] 
df1.head()
# Out:
#                       상호                            주소    가격 셀프      상표    구  \
# 0            (주)보성 세곡주유소         서울 강남구  헌릉로 731 (세곡동)  1623  Y   SK에너지  강남구
# 33        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)  2578  N   GS칼텍스  강남구
# 34  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1669  Y  현대오일뱅크  강동구
# 46                 광성주유소         서울 강동구 올림픽로 673 (천호동)  1978  N   S-OIL  강동구
# 47        SK에너지(주) 매일주유소          서울 강북구 삼양로 217 (미아동)  1629  Y   SK에너지  강북구
#
#     mm
# 0    1
# 33   2
# 34   1
# 46   2
# 47   1

# %%
df1.shape
# Out:
# (70, 7)

# %% [markdown]
# # 지도 시각화

# %%
# KAKAO API로 위,경도값을 추출
with open('./data1/kakao.txt') as file:
    kakao_key = file.read()

# %%
lat_list, lng_list = [], []
for i in df1.index:
    search_url = "https://dapi.kakao.com/v2/local/search/address.json"
    url = f'{search_url}?query={quote(df1.주소[i])}'
    result = requests.get(url,
        headers={"Authorization": f'KakaoAK {kakao_key}'}).json()
    try:
        lng_list.append(float(result['documents'][0]['x']))
        lat_list.append(float(result['documents'][0]['y']))
    except:
        print(df1.상호[i])

# %%
df1['위도'] = lat_list
df1['경도'] = lng_list
df1.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10092\2420660999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['위도'] = lat_list
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10092\2420660999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['경도'] = lng_list
#                       상호                            주소    가격 셀프      상표    구  \
# 0            (주)보성 세곡주유소         서울 강남구  헌릉로 731 (세곡동)  1623  Y   SK에너지  강남구
# 33        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)  2578  N   GS칼텍스  강남구
# 34  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1669  Y  현대오일뱅크  강동구
# 46                 광성주유소         서울 강동구 올림픽로 673 (천호동)  1978  N   S-OIL  강동구
# 47        SK에너지(주) 매일주유소          서울 강북구 삼양로 217 (미아동)  1629  Y   SK에너지  강북구
#
#     mm         위도          경도
# 0    1  37.467272  127.118743
# 33   2  37.511551  127.047115
# 34   1  37.536417  127.149372
# 46   2  37.541577  127.124242
# 47   1  37.622765  127.019086

# %%
# 지도위에 주유소 표시

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)
for i in df1.index:
    folium.Marker(
        location=[df1.위도[i], df1.경도[i]],
        popup=folium.Popup(df.주소[i], max_width=200),
        tooltip=f'{df1.상호[i]}<br>휘발유:{df1.가격[i]:,d}원',
        icon=folium.Icon(color='green' if df1.mm[i] == 1 else 'red',
                        icon = 'glyphicon glyphicon-thumbs-up' 
            if df1.mm[i] == 1 else 'glyphicon glyphicon-thumbs-down')
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc479b0abe6438193dc23605d268bf81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc479b0abe6438193dc23605d268bf81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc479b0abe6438193dc23605d268bf81 = L.map(
#                 &quot;map_fc479b0abe6438193dc23605d268bf81&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37c45b454eeb27be657aeb6db01f4fc7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fc479b0abe6438193dc23605d268bf81);
#
#
#             var marker_656100c11bdd7961d2ea1aa35e819635 = L.marker(
#                 [37.4672717183911, 127.118742598267],
#                 {}
#             ).addTo(map_fc479b0abe6438193dc23605d268bf81);
#
#
#             var icon_8a05ee0adf4430a0b22546143c083d05 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_656100c11bdd7961d2ea1aa35e819635.setIcon(icon_8a05ee0adf4430a0b22546143c083d05);
#
#
#         var popup_71089d5999e3cd95620db4533efd561f = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_b4988cfb3e56707d374d9e3c9966b037 = $(`&lt;div id=&quot;html_b4988cfb3e56707d374d9e3c9966b037&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울 강남구  헌릉로 731 (세곡동)&lt;/div&gt;`)[0];
#                 popup_71089d5999e3cd95620db4533efd561f.setContent(html_b4988cfb3e56707d374d9e3c9966b037);
#
#
#
#         marker_656100c11bdd7961d2ea1aa35e819635.bindPopup(popup_71089d5999e3cd95620db4533efd561f)
#         ;
#
#
#
#
#             marker_656100c11bdd7961d2ea1aa35e819635.bindTooltip(
#                 `&lt;div&gt;
#                      (주)보성 세곡주유소&lt;br&gt;휘발유:1,623원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dc45122fcc826830f247019a3becbed1 = L.marker(
#                 [37.5115512804432, 127.047114626083],
#                 {}
#             ).addTo(map_fc479b0abe6438193dc23605d268bf81);
#
#
#             var icon_7cc09dd9ff9e534e8307a5fa8f34b15a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc45122fcc826830f247019a3becbed1.setIcon(icon_7cc09dd9ff9e534e8307a5fa8f34b15a);
#
#
#         var popup_5f8c6535d610fec6e9fce46f6ad8a6bd = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_5aeda7393285bf745ccd11448a4ea6a0 = $(`&lt;div id=&quot;html_5aeda7393285bf745ccd11448a4ea6a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울 강남구 봉은사로 433 (삼성동)&lt;/div&gt;`)[0];
#                 popup_5f8c6535d610fec6e9fce46f6ad8a6bd.setContent(html_5aeda7393285bf745ccd11448a4ea6a0);
#
#
#
#         marker_dc45122fcc826830f247019a3becbed1.bindPopup(popup_5f8c6535d610fec6e9fce46f6ad8a6bd)
#         ;
#
#
#
#
#             marker_dc45122fcc826830f247019a3becbed1.bindTooltip(
#                 `&lt;div&gt;
#                      (주)만정에너지 삼보주유소&lt;br&gt;휘발유:2,578원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bbf84b60b5e179916f5426f38a9ab3cb = L.marker(
#                 [37.5364168582452, 127.149372429092],
#                 {}
#             ).addTo(map_fc479b0abe6438193dc23605d268bf81);
#
#
#             var icon_add77a47679c883c81fe511b8f78d65c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbf84b60b5e179916f5426f38a9ab3cb.setIcon(icon_add77a47679c883c81fe511b8f78d65c);
#
#
#         var popup_1a7b537bc5d5582d55aa7c26ff281331 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_a1e7eddf07155ca8dd3a00ffb1a248bd = $(`&lt;div id=&quot;html_a1e7eddf07155ca8dd3a00ffb1a248bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강동구  천호대로 1246 (둔촌제2동)&lt;/div&gt;`)[0];
#                 popup_1a7b537bc5

# %% [markdown]
# # 평균값으로 단계구분도 그리고 주유소 추가하기

# %%
filename = './gasData/skorea_municipalities_geo_simple.json'
geo_str = json.load(open(filename, encoding='utf-8'))

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=12, tiles='Stamen Toner')
folium.Choropleth(
    geo_data=geo_str,
    data=gu_mm['mean'],
    columns=[gu_mm.index, gu_mm['mean']],
    fill_color='PuRd',
    key_on='feature.id'
).add_to(map)
for i in df1.index:
    folium.Marker(
        location=[df1.위도[i], df1.경도[i]],
        popup=folium.Popup(df.주소[i], max_width=200),
        tooltip=f'{df1.상호[i]}<br>휘발유: {df1.가격[i]:,d}원',
        icon=folium.Icon(color='green' if df.mm[i] == 1 else 'red',
                         icon='glyphicon glyphicon-thumbs-up' if df.mm[i] == 1 \
                                  else 'glyphicon glyphicon-thumbs-down')
    ).add_to(map)   
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94afedd935ff4224708aa44140d3e362 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94afedd935ff4224708aa44140d3e362&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94afedd935ff4224708aa44140d3e362 = L.map(
#                 &quot;map_94afedd935ff4224708aa44140d3e362&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bc24132ed969b3c172fa5108b0509bb = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_94afedd935ff4224708aa44140d3e362);
#
#
#             var choropleth_41c8f3995537ccc6cc48b446a6959573 = L.featureGroup(
#                 {}
#             ).addTo(map_94afedd935ff4224708aa44140d3e362);
#
#
#         function geo_json_b6312f0674f40413754b0762e290a323_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b6312f0674f40413754b0762e290a323_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b6312f0674f40413754b0762e290a323 = L.geoJson(null, {
#                 onEachFeature: geo_json_b6312f0674f40413754b0762e290a323_onEachFeature,
#
#                 style: geo_json_b6312f0674f40413754b0762e290a323_styler,
#         });
#
#         function geo_json_b6312f0674f40413754b0762e290a323_add (data) {
#             geo_json_b6312f0674f40413754b0762e290a323
#                 .addData(data)
#                 .addTo(choropleth_41c8f3995537ccc6cc48b446a6959573);
#         }
#             geo_json_b6312f0674f40413754b0762e290a323_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;
